# %%
#시리즈생성 3가지 (create)

# %%
#시리즈인덱싱,슬라이싱

# %%
#CRUD
#추가(update),수정(update),삭제 (delete)
import pandas as pd

data = [100, 200, 300]
index = ['월', '화', '수']
s = pd.Series(data, index)

s.loc['목'] = 400 # 방법 1: loc 사용 (권장)
s['금'] = 500 # 방법 2: 대괄호 직접 사용
# s.iloc[6] = 600
s
s = s.astype('int16')
s.dtype

s.loc['월'] = 120 #수정
s.iloc[0] = 130 #생성 후 integer위치값으로는 수정이 된다.
s
#삭제  drop()
# s = s.drop('월')
# s.drop('월', inplace = True) #inplace는 원본에 반영
# s
# s.drop(['화','수','목'], inplace = True) #여러개삭제는  []로 묶는다.
# s
# Out:
# 월    130
# 화    200
# 수    300
# 목    400
# 금    500
# dtype: int16
